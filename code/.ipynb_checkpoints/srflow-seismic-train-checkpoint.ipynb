# %% [markdown]
# # SRFlow Jupyter Notebook Implementation (PyTorch)

# %% [markdown]
# ### SRFlow Official Github (Python + PyTorch): https://github.com/andreas128/SRFlow

# %% [markdown]
# ### 1. Import Libraries

# %%
import os
from os.path import basename
import math
import argparse
import random
import logging
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt
import pickle


import torch
import torch.distributed as dist
import torch.multiprocessing as mp

import options.options as option
from utils import util
from data import create_dataloader, create_dataset
from models import create_model
from utils.timer import Timer, TickTock
from utils.util import get_resume_paths

# %%
## version check 
print('pytorch + cuda version =', torch.__version__)
## GPU count
print('gpu num =', torch.cuda.device_count())
# Out:
# pytorch + cuda version = 1.8.1+cu101
# gpu num = 8

# %%
## Official code run 
# !python train.py -opt ./confs/SRFlow_DF2K_4X.yml

# %%
# define function of ricker wavelet
def ricker(f, length, dt):
    t0 = np.arange(-length/2, (length-dt)/2, dt)
    y = (1.0 - 2.0*(np.pi**2)*(f**2)*(t0**2)) * np.exp(-(np.pi**2)*(f**2)*(t0**2))
    return t0, y


def gen2d(l,x,ratio):
    geo = []
    for i in range(l):
        ran = random.randint(1,30)
        ai = random.gauss(0.5*1e7+i/100*1e7, random.gauss(i*0.01,i*0.005)*2329247)
        for j in range(ran):
            geo.append(ai)    
            
    geo_2d = np.zeros(shape=[x,l])
    for i in range(x):
        geo_2d[i,:] = geo[:l]

    
    ### squeeze ###
    img = geo_2d.T
    A = img.shape[0] / 10.0
    w = (random.randint(0,20)/10+0.01) / img.shape[1]

    shift = lambda z: A * np.sin(1.0*np.pi*z * w) 

    for i in range(img.shape[0]):
        img[:,i] = np.roll(img[:,i], int(shift(i)))
    
    geo_2d = img[:].T 
    
    
    
    l_t = int(l/ratio)
    ref_2d = np.zeros(shape=[x,l_t])
    
    for i in range(x):
        ai_avg = []
        ref_avg= []
        
        for j in range(0, l, ratio):
            slice_from_index = j
            slice_to_index = slice_from_index + ratio
            ai_avg.append(np.mean(geo_2d[i,slice_from_index:slice_to_index]))

        for k in range(l_t-1):
            ref_avg.append((ai_avg[k+1]-ai_avg[k])/(ai_avg[k]+ai_avg[k+1]))
            
        ref_avg.append(ref_avg[-1])
        ref_2d[i,:] = ref_avg
    
    
    f=100  #20         #wavelet frequency
    length=0.1#0.512    #Wavelet vector length
    dt=0.001  # Sampling prefer to use smiliar to resampled AI
    t0, w = ricker (f, length, dt) # ricker wavelet 
    
    syn_2d = np.zeros(shape=[x,l_t]) 
    for i in range(x):
        syn_2d[i,:] = np.convolve(w, ref_2d[i,:], mode='same')
    
    
    return geo_2d, ref_2d, syn_2d

# %%
from matplotlib.ticker import LinearLocator,AutoLocator
geo2d,ref2d,syn2d= gen2d(1000,1000,4)

# %%
# for i in range(200):
#         geo2d,ref2d,syn2d= gen2d(1000,1000,4)
#         np.save('/sep/minjun/srflow/datasets/mj_data/hr/hr%d.npy'%i,geo2d)
#         np.save('/sep/minjun/srflow/datasets/mj_data/lr/lr%d.npy'%i,syn2d)

# %%
# for i in range(10):
#         geo2d,ref2d,syn2d= gen2d(1000,1000,4)
#         np.save('/sep/minjun/srflow/datasets/mj_data_test/hr/hr%d.npy'%i,geo2d)
#         np.save('/sep/minjun/srflow/datasets/mj_data_test/lr/lr%d.npy'%i,syn2d)

# %%
fig, ax = plt.subplots(1,3,figsize=(13,5))
v=0.2
ax[0].imshow(geo2d.T,aspect='auto')#,extent=[0,nx*dx/100,((nt-1)*dt*10),0.0])
ax[0].tick_params(labelsize=15)
ax[0].set_title('Acoustic Impedance', fontsize=15)

ax[1].imshow(ref2d.T,cmap='gray',aspect='auto')#,extent=[0,nx*dx/100,((nt-1)*dt*10),0.0])
ax[1].tick_params(labelsize=15)
ax[1].set_title('Reflection Coef',fontsize=15)

ax[2].imshow(syn2d.T,cmap='gray',aspect='auto')#,extent=[0,nx*dx/100,((nt-1)*dt*10),0.0])
ax[2].tick_params(labelsize=15)
ax[2].set_title('Seismic',fontsize=15)
plt.tight_layout()
plt.show()

# %%
from prepare_data_seismic import *


hrs = []
lqs = []
dir_path_hr = '/sep/minjun/srflow/datasets/mj_data/hr'
dir_path_lr = '/sep/minjun/srflow/datasets/mj_data/lr'


for i in range(200):
    hr = np.load('/sep/minjun/srflow/datasets/mj_data/hr/hr%d.npy'%i)
    lr = np.load('/sep/minjun/srflow/datasets/mj_data/lr/lr%d.npy'%i) 
    for j in range(20):
        hr_crop, lr_crop = random_crop(hr,lr, 80)
        hrs.append(hr_crop)
        lqs.append(lr_crop)

shuffle_combined(hrs, lqs)

hrs_path = get_hrs_path(dir_path_hr)
to_pklv4(hrs, hrs_path, vebose=True)
to_pklv4_1pct(hrs, hrs_path, vebose=True)

lqs_path = get_lqs_path(dir_path_lr)
to_pklv4(lqs, lqs_path, vebose=True)
to_pklv4_1pct(lqs, lqs_path, vebose=True)
# Out:
# Wrote /sep/minjun/srflow/datasets/mj_data/pkls/hr.pklv4
# Wrote /sep/minjun/srflow/datasets/mj_data/pkls/hr_1pct.pklv4
# Wrote /sep/minjun/srflow/datasets/mj_data/pkls/lr_X4.pklv4
# Wrote /sep/minjun/srflow/datasets/mj_data/pkls/lr_X4_1pct.pklv4

# %%
def getEnv(name): import os; return True if name in os.environ.keys() else False

def init_dist(backend='nccl', **kwargs):
    ''' initialization for distributed training'''
    # if mp.get_start_method(allow_none=True) is None:
    if mp.get_start_method(allow_none=True) != 'spawn':
        mp.set_start_method('spawn')
    rank = int(os.environ['RANK'])
    num_gpus = torch.cuda.device_count()
    torch.cuda.set_deviceDistIterSampler(rank % num_gpus)
    dist.init_process_group(backend=backend, **kwargs)


## argparse in Jupyter notebook 
## read YAML file 
args = argparse.Namespace(
  opt='./confs/SRFlow_DF2K_4X.yml',
  launcher='none',
  local_rank=0
)
opt = option.parse(args.opt, is_train=True)

# %%
from torch.utils.data import TensorDataset


l = 1000
x = 500
ratio =4 
n = 20

HR = np.zeros(shape=[n,1,x,l])
LR = np.zeros(shape=[n,1,x,int(l/ratio)])

for i in range(n):
    HR[i,0,:,:],_,LR[i,0,:,:] = gen2d(l,x,ratio)
    
HR = HR/np.max(HR)

HR_torch = torch.Tensor(HR)
LR_torch = torch.Tensor(LR)

train_set = TensorDataset(LR_torch, HR_torch)

# %%
 opt["dataroot_GT"]
# Out:
# '/sep/minjun/srflow/datasets/div2k-validation-modcrop8-gt'

# %%
#### distributed training settings
opt['dist'] = False
rank = -1
print('Disabled distributed training.')

#### loading resume state if exists
if opt['path'].get('resume_state', None):
    resume_state_path, _ = get_resume_paths(opt)

    # distributed resuming: all load into default GPU
    if resume_state_path is None:
        resume_state = None
    else:
        device_id = torch.cuda.current_device()
        resume_state = torch.load(resume_state_path,
                                  map_location=lambda storage, loc: storage.cuda(device_id))
        option.check_resume(opt, resume_state['iter'])  # check resume options
else:
    resume_state = None

#### mkdir and loggers
if rank <= 0:  # normal training (rank -1) OR distributed training (rank 0)
    if resume_state is None:
        util.mkdir_and_rename(
            opt['path']['experiments_root'])  # rename experiment folder if exists
        util.mkdirs((path for key, path in opt['path'].items() if not key == 'experiments_root'
                     and 'pretrain_model' not in key and 'resume' not in key))

    # config loggers. Before it, the log will not work
    util.setup_logger('base', opt['path']['log'], 'train_' + opt['name'], level=logging.INFO,
                      screen=True, tofile=True)
    util.setup_logger('val', opt['path']['log'], 'val_' + opt['name'], level=logging.INFO,
                      screen=True, tofile=True)
    logger = logging.getLogger('base')
    logger.info(option.dict2str(opt))

    # tensorboard logger
    if opt.get('use_tb_logger', False) and 'debug' not in opt['name']:
        version = float(torch.__version__[0:3])
        if version >= 1.1:  # PyTorch 1.1
            from torch.utils.tensorboard import SummaryWriter
        else:
            logger.info(
                'You are using PyTorch {}. Tensorboard will use [tensorboardX]'.format(version))
            from tensorboardX import SummaryWriter
        conf_name = basename(args.opt).replace(".yml", "")
        exp_dir = opt['path']['experiments_root']
        log_dir_train = os.path.join(exp_dir, 'tb', conf_name, 'train')
        log_dir_valid = os.path.join(exp_dir, 'tb', conf_name, 'valid')
        tb_logger_train = SummaryWriter(log_dir=log_dir_train)
        tb_logger_valid = SummaryWriter(log_dir=log_dir_valid)
else:
    util.setup_logger('base', opt['path']['log'], 'train', level=logging.INFO, screen=True)
    logger = logging.getLogger('base')

# convert to NoneDict, which returns None for missing keys
opt = option.dict_to_nonedict(opt)

#### random seed
seed = opt['train']['manual_seed']
if seed is None:
    seed = random.randint(1, 10000)
if rank <= 0:
    logger.info('Random seed: {}'.format(seed))
util.set_random_seed(seed)

torch.backends.cudnn.benchmark = True
# torch.backends.cudnn.deterministic = True

# #### create train and val dataloader
# dataset_ratio = 200  # enlarge the size of each epoch
# for phase, dataset_opt in opt['datasets'].items():
#     if phase == 'train':
#         #train_set = create_dataset(dataset_opt)
#         train_set = {'LQ': LR_torch, 'GT': HR_torch}
#         print('Dataset created')
#         train_size = int(math.ceil(len(train_set) / dataset_opt['batch_size']))
#         total_iters = int(opt['train']['niter'])
#         total_epochs = int(math.ceil(total_iters / train_size))
#         train_sampler = None
#         train_loader = create_dataloader(train_set, dataset_opt, opt, train_sampler)
#         if rank <= 0:
#             logger.info('Number of train images: {:,d}, iters: {:,d}'.format(
#                 len(train_set), train_size))
#             logger.info('Total epochs needed: {:d} for iters {:,d}'.format(
#                 total_epochs, total_iters))
#     elif phase == 'val':
#         val_set = create_dataset(dataset_opt)
#         val_loader = create_dataloader(val_set, dataset_opt, opt, None)
#         if rank <= 0:
#             logger.info('Number of val images in [{:s}]: {:d}'.format(
#                 dataset_opt['name'], len(val_set)))
#     else:
#         raise NotImplementedError('Phase [{:s}] is not recognized.'.format(phase))
# assert train_loader is not None
# Out:
# Disabled distributed training.
# pretrain_model path will be ignored when resuming training.
# 21-07-06 12:20:34.022 - INFO:   name: train
#   use_tb_logger: True
#   model: SRFlow
#   distortion: sr
#   scale: 4
#   gpu_ids: [0]
#   datasets:[
#     train:[
#       name: CelebA_160_tr
#       mode: LRHR_PKL
#       dataroot_GT: /sep/minjun/srflow/datasets/DF2K-tr.pklv4
#       dataroot_LQ: /sep/minjun/srflow/datasets/DF2K-tr_X4.pklv4
#       quant: 32
#       use_shuffle: True
#       n_workers: 3
#       batch_size: 12
#       GT_size: 160
#       use_flip: True
#       color: RGB
#       phase: train
#       scale: 4
#       data_type: img
#     ]
#     val:[
#       name: CelebA_160_va
#       mode: LRHR_PKL
#       dataroot_GT: /sep/minjun/srflow/datasets/DIV2K-va.pklv4
#       dataroot_LQ: /sep/minjun/srflow/datasets/DIV2K-va_X4.pklv4
#       quant: 32
#       n_max: 20
#       phase: val
#       scale: 4
#       data_type: img
#     ]
#   ]
#   dataroot_GT: /sep/minjun/srflow/datasets/div2k-validation-modcrop8-gt
#   dataroot_LR: /sep/minjun/srflow/datasets/div2k-validation-modcrop8-x4
#   model_path: /sep/minjun/srflow/pretrained_models/SRFlow_DF2K_4X.pth
#   heat: 0.9
#   network_G:[
#     which_model_G: SRFlowNet
#     in_nc: 3
#     out_nc: 3
#     nf: 64
#     nb: 23
#     upscale: 4
#     train_RRDB: False
#     train_RRDB_delay: 0.5
#     flow:[
#       K: 16
#       L: 3
#       noInitialInj: True
#       coupling: CondAffineSeparatedAndCond
#       additionalFlowNoAffine: 2
#       split:[
#         enable: True
#       ]
#       fea_up0: True
#       stackRRDB:[
#         blocks: [1, 8, 15, 22]
#         concat: True
#       ]
#     ]
#     scale: 4
#   ]
#   path:[
#     pretrain_model_G: /net/server2/homes/sep/minjun/research/SRFlow/experiments/train/models/4000_G.pth
#     strict_load: True
#     resume_state: auto
#     root: /net/server2/homes/sep/minjun/research/SRFlow
#     experiments_root: /net/server2/homes/sep/minjun/research/SRFlow/experiments/train
#     models: /net/server2/homes/sep/minjun/research/SRFlow/experiments/train/models
#     training_state: /net/server2/homes/sep/minjun/research/SRFlow/experiments/train/training_state
#     log: /net/server2/homes/sep/minjun/research/SRFlow/experiments/train
#     val_images: /net/server2/homes/sep/minjun/research/SRFlow/experiments/train/val_images
#   ]
#   train:[
#     manual_seed: 10
#     lr_G: 0.00025
#     weight_decay_G: 0
#     beta1: 0.9
#     beta2: 0.99
#     lr_scheme: MultiStepLR
#     warmup_iter: -1
#     lr_steps_rel: [0.5, 0.75, 0.9, 0.95]
#     lr_gamma: 0.5
#     niter: 200000
#     val_freq: 40000
#     lr_steps: [100000, 150000, 180000, 190000]
#   ]
#   val:[
#     heats: [0.0, 0.5, 0.75, 1.0]
#     n_sample: 3
#   ]
#   logger:[
#     print_freq: 100
#     save_checkpoint_freq: 1000.0
#   ]
#   is_train: True
#   dist: False
#
# 21-07-06 12:20:34.323 - INFO: Random seed: 10

# %%
#### create model
current_step = 0 if resume_state is None else resume_state['iter']
model = create_model(opt, current_step)
# Out:
# <class 'models.SRFlow_model.SRFlowModel'>
# 21-07-06 12:20:43.685 - INFO: Network G structure: DataParallel - SRFlowNet, with parameters: 39,541,811
# 21-07-06 12:20:43.687 - INFO: SRFlowNet(
#   (RRDB): RRDBNet(
#     (conv_first): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (RRDB_trunk): Sequential(
#       (0): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (1): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (2): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (3): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (4): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (5): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (6): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (7): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (8): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (9): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (10): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (11): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (12): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (13): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (14): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (15): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (16): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (17): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (18): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (19): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (20): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (21): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#       (22): RRDB(
#         (RDB1): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB2): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#         (RDB3): ResidualDenseBlock_5C(
#           (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#         )
#       )
#     )
#     (trunk_conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (upconv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (upconv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (HRconv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_last): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (flowUpsamplerNet): FlowUpsamplerNet(
#     (layers): ModuleList(
#       (0): SqueezeLayer()
#       (1): FlowStep(
#         (actnorm): ActNorm2d()
#         (invconv): InvertibleConv1x1()
#       )
#       (2): FlowStep(
#         (actnorm): ActNorm2d()
#         (invconv): InvertibleConv1x1()
#       )
#       (3): FlowStep(
#         (actnorm): ActNorm2d()
#         (invconv): InvertibleConv1x1()
#         (affine): CondAffineSeparatedAndCond(
#           (fAffine): Sequential(
#             (0): Conv2d(
#               326, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 12, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#           (fFeatures): Sequential(
#             (0): Conv2d(
#               320, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 24, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#         )
#       )
#       (4): FlowStep(
#         (actnorm): ActNorm2d()
#         (invconv): InvertibleConv1x1()
#         (affine): CondAffineSeparatedAndCond(
#           (fAffine): Sequential(
#             (0): Conv2d(
#               326, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 12, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#           (fFeatures): Sequential(
#             (0): Conv2d(
#               320, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 24, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#         )
#       )
#       (5): FlowStep(
#         (actnorm): ActNorm2d()
#         (invconv): InvertibleConv1x1()
#         (affine): CondAffineSeparatedAndCond(
#           (fAffine): Sequential(
#             (0): Conv2d(
#               326, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 12, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#           (fFeatures): Sequential(
#             (0): Conv2d(
#               320, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 24, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#         )
#       )
#       (6): FlowStep(
#         (actnorm): ActNorm2d()
#         (invconv): InvertibleConv1x1()
#         (affine): CondAffineSeparatedAndCond(
#           (fAffine): Sequential(
#             (0): Conv2d(
#               326, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 12, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#           (fFeatures): Sequential(
#             (0): Conv2d(
#               320, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 24, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#         )
#       )
#       (7): FlowStep(
#         (actnorm): ActNorm2d()
#         (invconv): InvertibleConv1x1()
#         (affine): CondAffineSeparatedAndCond(
#           (fAffine): Sequential(
#             (0): Conv2d(
#               326, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 12, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#           (fFeatures): Sequential(
#             (0): Conv2d(
#               320, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 24, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#         )
#       )
#       (8): FlowStep(
#         (actnorm): ActNorm2d()
#         (invconv): InvertibleConv1x1()
#         (affine): CondAffineSeparatedAndCond(
#           (fAffine): Sequential(
#             (0): Conv2d(
#               326, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 12, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#           (fFeatures): Sequential(
#             (0): Conv2d(
#               320, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 24, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#         )
#       )
#       (9): FlowStep(
#         (actnorm): ActNorm2d()
#         (invconv): InvertibleConv1x1()
#         (affine): CondAffineSeparatedAndCond(
#           (fAffine): Sequential(
#             (0): Conv2d(
#               326, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 12, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#           (fFeatures): Sequential(
#             (0): Conv2d(
#               320, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 24, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#         )
#       )
#       (10): FlowStep(
#         (actnorm): ActNorm2d()
#         (invconv): InvertibleConv1x1()
#         (affine): CondAffineSeparatedAndCond(
#           (fAffine): Sequential(
#             (0): Conv2d(
#               326, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 12, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#           (fFeatures): Sequential(
#             (0): Conv2d(
#               320, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
# ...
# module.flowUpsamplerNet.layers.49.affine.fAffine.2.actnorm.logs True
# module.flowUpsamplerNet.layers.49.affine.fAffine.4.weight True
# module.flowUpsamplerNet.layers.49.affine.fAffine.4.bias True
# module.flowUpsamplerNet.layers.49.affine.fAffine.4.logs True
# module.flowUpsamplerNet.layers.49.affine.fFeatures.0.weight True
# module.flowUpsamplerNet.layers.49.affine.fFeatures.0.actnorm.bias True
# module.flowUpsamplerNet.layers.49.affine.fFeatures.0.actnorm.logs True
# module.flowUpsamplerNet.layers.49.affine.fFeatures.2.weight True
# module.flowUpsamplerNet.layers.49.affine.fFeatures.2.actnorm.bias True
# module.flowUpsamplerNet.layers.49.affine.fFeatures.2.actnorm.logs True
# module.flowUpsamplerNet.layers.49.affine.fFeatures.4.weight True
# module.flowUpsamplerNet.layers.49.affine.fFeatures.4.bias True
# module.flowUpsamplerNet.layers.49.affine.fFeatures.4.logs True
# module.flowUpsamplerNet.layers.50.actnorm.bias True
# module.flowUpsamplerNet.layers.50.actnorm.logs True
# module.flowUpsamplerNet.layers.50.invconv.weight True
# module.flowUpsamplerNet.layers.50.affine.fAffine.0.weight True
# module.flowUpsamplerNet.layers.50.affine.fAffine.0.actnorm.bias True
# module.flowUpsamplerNet.layers.50.affine.fAffine.0.actnorm.logs True
# module.flowUpsamplerNet.layers.50.affine.fAffine.2.weight True
# module.flowUpsamplerNet.layers.50.affine.fAffine.2.actnorm.bias True
# module.flowUpsamplerNet.layers.50.affine.fAffine.2.actnorm.logs True
# module.flowUpsamplerNet.layers.50.affine.fAffine.4.weight True
# module.flowUpsamplerNet.layers.50.affine.fAffine.4.bias True
# module.flowUpsamplerNet.layers.50.affine.fAffine.4.logs True
# module.flowUpsamplerNet.layers.50.affine.fFeatures.0.weight True
# module.flowUpsamplerNet.layers.50.affine.fFeatures.0.actnorm.bias True
# module.flowUpsamplerNet.layers.50.affine.fFeatures.0.actnorm.logs True
# module.flowUpsamplerNet.layers.50.affine.fFeatures.2.weight True
# module.flowUpsamplerNet.layers.50.affine.fFeatures.2.actnorm.bias True
# module.flowUpsamplerNet.layers.50.affine.fFeatures.2.actnorm.logs True
# module.flowUpsamplerNet.layers.50.affine.fFeatures.4.weight True
# module.flowUpsamplerNet.layers.50.affine.fFeatures.4.bias True
# module.flowUpsamplerNet.layers.50.affine.fFeatures.4.logs True
# module.flowUpsamplerNet.layers.51.actnorm.bias True
# module.flowUpsamplerNet.layers.51.actnorm.logs True
# module.flowUpsamplerNet.layers.51.invconv.weight True
# module.flowUpsamplerNet.layers.51.affine.fAffine.0.weight True
# module.flowUpsamplerNet.layers.51.affine.fAffine.0.actnorm.bias True
# module.flowUpsamplerNet.layers.51.affine.fAffine.0.actnorm.logs True
# module.flowUpsamplerNet.layers.51.affine.fAffine.2.weight True
# module.flowUpsamplerNet.layers.51.affine.fAffine.2.actnorm.bias True
# module.flowUpsamplerNet.layers.51.affine.fAffine.2.actnorm.logs True
# module.flowUpsamplerNet.layers.51.affine.fAffine.4.weight True
# module.flowUpsamplerNet.layers.51.affine.fAffine.4.bias True
# module.flowUpsamplerNet.layers.51.affine.fAffine.4.logs True
# module.flowUpsamplerNet.layers.51.affine.fFeatures.0.weight True
# module.flowUpsamplerNet.layers.51.affine.fFeatures.0.actnorm.bias True
# module.flowUpsamplerNet.layers.51.affine.fFeatures.0.actnorm.logs True
# module.flowUpsamplerNet.layers.51.affine.fFeatures.2.weight True
# module.flowUpsamplerNet.layers.51.affine.fFeatures.2.actnorm.bias True
# module.flowUpsamplerNet.layers.51.affine.fFeatures.2.actnorm.logs True
# module.flowUpsamplerNet.layers.51.affine.fFeatures.4.weight True
# module.flowUpsamplerNet.layers.51.affine.fFeatures.4.bias True
# module.flowUpsamplerNet.layers.51.affine.fFeatures.4.logs True
# module.flowUpsamplerNet.layers.52.actnorm.bias True
# module.flowUpsamplerNet.layers.52.actnorm.logs True
# module.flowUpsamplerNet.layers.52.invconv.weight True
# module.flowUpsamplerNet.layers.52.affine.fAffine.0.weight True
# module.flowUpsamplerNet.layers.52.affine.fAffine.0.actnorm.bias True
# module.flowUpsamplerNet.layers.52.affine.fAffine.0.actnorm.logs True
# module.flowUpsamplerNet.layers.52.affine.fAffine.2.weight True
# module.flowUpsamplerNet.layers.52.affine.fAffine.2.actnorm.bias True
# module.flowUpsamplerNet.layers.52.affine.fAffine.2.actnorm.logs True
# module.flowUpsamplerNet.layers.52.affine.fAffine.4.weight True
# module.flowUpsamplerNet.layers.52.affine.fAffine.4.bias True
# module.flowUpsamplerNet.layers.52.affine.fAffine.4.logs True
# module.flowUpsamplerNet.layers.52.affine.fFeatures.0.weight True
# module.flowUpsamplerNet.layers.52.affine.fFeatures.0.actnorm.bias True
# module.flowUpsamplerNet.layers.52.affine.fFeatures.0.actnorm.logs True
# module.flowUpsamplerNet.layers.52.affine.fFeatures.2.weight True
# module.flowUpsamplerNet.layers.52.affine.fFeatures.2.actnorm.bias True
# module.flowUpsamplerNet.layers.52.affine.fFeatures.2.actnorm.logs True
# module.flowUpsamplerNet.layers.52.affine.fFeatures.4.weight True
# module.flowUpsamplerNet.layers.52.affine.fFeatures.4.bias True
# module.flowUpsamplerNet.layers.52.affine.fFeatures.4.logs True
# module.flowUpsamplerNet.layers.53.actnorm.bias True
# module.flowUpsamplerNet.layers.53.actnorm.logs True
# module.flowUpsamplerNet.layers.53.invconv.weight True
# module.flowUpsamplerNet.layers.53.affine.fAffine.0.weight True
# module.flowUpsamplerNet.layers.53.affine.fAffine.0.actnorm.bias True
# module.flowUpsamplerNet.layers.53.affine.fAffine.0.actnorm.logs True
# module.flowUpsamplerNet.layers.53.affine.fAffine.2.weight True
# module.flowUpsamplerNet.layers.53.affine.fAffine.2.actnorm.bias True
# module.flowUpsamplerNet.layers.53.affine.fAffine.2.actnorm.logs True
# module.flowUpsamplerNet.layers.53.affine.fAffine.4.weight True
# module.flowUpsamplerNet.layers.53.affine.fAffine.4.bias True
# module.flowUpsamplerNet.layers.53.affine.fAffine.4.logs True
# module.flowUpsamplerNet.layers.53.affine.fFeatures.0.weight True
# module.flowUpsamplerNet.layers.53.affine.fFeatures.0.actnorm.bias True
# module.flowUpsamplerNet.layers.53.affine.fFeatures.0.actnorm.logs True
# module.flowUpsamplerNet.layers.53.affine.fFeatures.2.weight True
# module.flowUpsamplerNet.layers.53.affine.fFeatures.2.actnorm.bias True
# module.flowUpsamplerNet.layers.53.affine.fFeatures.2.actnorm.logs True
# module.flowUpsamplerNet.layers.53.affine.fFeatures.4.weight True
# module.flowUpsamplerNet.layers.53.affine.fFeatures.4.bias True
# module.flowUpsamplerNet.layers.53.affine.fFeatures.4.logs True
# module.flowUpsamplerNet.layers.54.actnorm.bias True
# module.flowUpsamplerNet.layers.54.actnorm.logs True
# module.flowUpsamplerNet.layers.54.invconv.weight True
# module.flowUpsamplerNet.layers.54.affine.fAffine.0.weight True
# module.flowUpsamplerNet.layers.54.affine.fAffine.0.actnorm.bias True
# module.flowUpsamplerNet.layers.54.affine.fAffine.0.actnorm.logs True
# module.flowUpsamplerNet.layers.54.affine.fAffine.2.weight True
# module.flowUpsamplerNet.layers.54.affine.fAffine.2.actnorm.bias True
# module.flowUpsamplerNet.layers.54.affine.fAffine.2.actnorm.logs True
# module.flowUpsamplerNet.layers.54.affine.fAffine.4.weight True
# module.flowUpsamplerNet.layers.54.affine.fAffine.4.bias True
# module.flowUpsamplerNet.layers.54.affine.fAffine.4.logs True
# module.flowUpsamplerNet.layers.54.affine.fFeatures.0.weight True
# module.flowUpsamplerNet.layers.54.affine.fFeatures.0.actnorm.bias True
# module.flowUpsamplerNet.layers.54.affine.fFeatures.0.actnorm.logs True
# module.flowUpsamplerNet.layers.54.affine.fFeatures.2.weight True
# module.flowUpsamplerNet.layers.54.affine.fFeatures.2.actnorm.bias True
# module.flowUpsamplerNet.layers.54.affine.fFeatures.2.actnorm.logs True
# module.flowUpsamplerNet.layers.54.affine.fFeatures.4.weight True
# module.flowUpsamplerNet.layers.54.affine.fFeatures.4.bias True
# module.flowUpsamplerNet.layers.54.affine.fFeatures.4.logs True
# module.flowUpsamplerNet.layers.55.actnorm.bias True
# module.flowUpsamplerNet.layers.55.actnorm.logs True
# module.flowUpsamplerNet.layers.55.invconv.weight True
# module.flowUpsamplerNet.layers.55.affine.fAffine.0.weight True
# module.flowUpsamplerNet.layers.55.affine.fAffine.0.actnorm.bias True
# module.flowUpsamplerNet.layers.55.affine.fAffine.0.actnorm.logs True
# module.flowUpsamplerNet.layers.55.affine.fAffine.2.weight True
# module.flowUpsamplerNet.layers.55.affine.fAffine.2.actnorm.bias True
# module.flowUpsamplerNet.layers.55.affine.fAffine.2.actnorm.logs True
# module.flowUpsamplerNet.layers.55.affine.fAffine.4.weight True
# module.flowUpsamplerNet.layers.55.affine.fAffine.4.bias True
# module.flowUpsamplerNet.layers.55.affine.fAffine.4.logs True
# module.flowUpsamplerNet.layers.55.affine.fFeatures.0.weight True
# module.flowUpsamplerNet.layers.55.affine.fFeatures.0.actnorm.bias True
# module.flowUpsamplerNet.layers.55.affine.fFeatures.0.actnorm.logs True
# module.flowUpsamplerNet.layers.55.affine.fFeatures.2.weight True
# module.flowUpsamplerNet.layers.55.affine.fFeatures.2.actnorm.bias True
# module.flowUpsamplerNet.layers.55.affine.fFeatures.2.actnorm.logs True
# module.flowUpsamplerNet.layers.55.affine.fFeatures.4.weight True
# module.flowUpsamplerNet.layers.55.affine.fFeatures.4.bias True
# module.flowUpsamplerNet.layers.55.affine.fFeatures.4.logs True
# module.flowUpsamplerNet.layers.56.actnorm.bias True
# module.flowUpsamplerNet.layers.56.actnorm.logs True
# module.flowUpsamplerNet.layers.56.invconv.weight True
# module.flowUpsamplerNet.layers.56.affine.fAffine.0.weight True
# module.flowUpsamplerNet.layers.56.affine.fAffine.0.actnorm.bias True
# module.flowUpsamplerNet.layers.56.affine.fAffine.0.actnorm.logs True
# module.flowUpsamplerNet.layers.56.affine.fAffine.2.weight True
# module.flowUpsamplerNet.layers.56.affine.fAffine.2.actnorm.bias True
# module.flowUpsamplerNet.layers.56.affine.fAffine.2.actnorm.logs True
# 21-07-06 12:20:45.654 - WARNING: Params [module.flowUpsamplerNet.layers.56.affine.fAffine.4.weight] will not optimize.
# 21-07-06 12:20:45.655 - WARNING: Params [module.flowUpsamplerNet.layers.56.affine.fAffine.4.bias] will not optimize.
# 21-07-06 12:20:45.655 - WARNING: Params [module.flowUpsamplerNet.layers.56.affine.fAffine.4.logs] will not optimize.
# 21-07-06 12:20:45.656 - WARNING: Params [module.flowUpsamplerNet.layers.56.affine.fFeatures.0.weight] will not optimize.
# 21-07-06 12:20:45.656 - WARNING: Params [module.flowUpsamplerNet.layers.56.affine.fFeatures.0.actnorm.bias] will not optimize.
# 21-07-06 12:20:45.657 - WARNING: Params [module.flowUpsamplerNet.layers.56.affine.fFeatures.0.actnorm.logs] will not optimize.
# 21-07-06 12:20:45.657 - WARNING: Params [module.flowUpsamplerNet.layers.56.affine.fFeatures.2.weight] will not optimize.
# 21-07-06 12:20:45.658 - WARNING: Params [module.flowUpsamplerNet.layers.56.affine.fFeatures.2.actnorm.bias] will not optimize.
# 21-07-06 12:20:45.658 - WARNING: Params [module.flowUpsamplerNet.layers.56.affine.fFeatures.2.actnorm.logs] will not optimize.
# 21-07-06 12:20:45.659 - WARNING: Params [module.flowUpsamplerNet.layers.56.affine.fFeatures.4.weight] will not optimize.
# 21-07-06 12:20:45.659 - WARNING: Params [module.flowUpsamplerNet.layers.56.affine.fFeatures.4.bias] will not optimize.
# 21-07-06 12:20:45.660 - WARNING: Params [module.flowUpsamplerNet.layers.56.affine.fFeatures.4.logs] will not optimize.
# 21-07-06 12:20:45.660 - WARNING: Params [module.flowUpsamplerNet.layers.57.actnorm.bias] will not optimize.
# 21-07-06 12:20:45.661 - WARNING: Params [module.flowUpsamplerNet.layers.57.actnorm.logs] will not optimize.
# 21-07-06 12:20:45.661 - WARNING: Params [module.flowUpsamplerNet.layers.57.invconv.weight] will not optimize.
# 21-07-06 12:20:45.662 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fAffine.0.weight] will not optimize.
# 21-07-06 12:20:45.662 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fAffine.0.actnorm.bias] will not optimize.
# 21-07-06 12:20:45.663 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fAffine.0.actnorm.logs] will not optimize.
# 21-07-06 12:20:45.663 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fAffine.2.weight] will not optimize.
# 21-07-06 12:20:45.664 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fAffine.2.actnorm.bias] will not optimize.
# 21-07-06 12:20:45.664 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fAffine.2.actnorm.logs] will not optimize.
# 21-07-06 12:20:45.665 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fAffine.4.weight] will not optimize.
# 21-07-06 12:20:45.665 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fAffine.4.bias] will not optimize.
# 21-07-06 12:20:45.665 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fAffine.4.logs] will not optimize.
# 21-07-06 12:20:45.666 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fFeatures.0.weight] will not optimize.
# 21-07-06 12:20:45.666 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fFeatures.0.actnorm.bias] will not optimize.
# 21-07-06 12:20:45.667 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fFeatures.0.actnorm.logs] will not optimize.
# 21-07-06 12:20:45.667 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fFeatures.2.weight] will not optimize.
# 21-07-06 12:20:45.668 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fFeatures.2.actnorm.bias] will not optimize.
# 21-07-06 12:20:45.668 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fFeatures.2.actnorm.logs] will not optimize.
# 21-07-06 12:20:45.669 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fFeatures.4.weight] will not optimize.
# 21-07-06 12:20:45.669 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fFeatures.4.bias] will not optimize.
# 21-07-06 12:20:45.670 - WARNING: Params [module.flowUpsamplerNet.layers.57.affine.fFeatures.4.logs] will not optimize.
# 21-07-06 12:20:45.670 - WARNING: Params [module.flowUpsamplerNet.f.0.weight] will not optimize.
# 21-07-06 12:20:45.671 - WARNING: Params [module.flowUpsamplerNet.f.0.bias] will not optimize.
# 21-07-06 12:20:45.673 - INFO: Model [SRFlowModel] is created.
# module.flowUpsamplerNet.layers.56.affine.fAffine.4.weight True
# module.flowUpsamplerNet.layers.56.affine.fAffine.4.bias True
# module.flowUpsamplerNet.layers.56.affine.fAffine.4.logs True
# module.flowUpsamplerNet.layers.56.affine.fFeatures.0.weight True
# module.flowUpsamplerNet.layers.56.affine.fFeatures.0.actnorm.bias True
# module.flowUpsamplerNet.layers.56.affine.fFeatures.0.actnorm.logs True
# module.flowUpsamplerNet.layers.56.affine.fFeatures.2.weight True
# module.flowUpsamplerNet.layers.56.affine.fFeatures.2.actnorm.bias True
# module.flowUpsamplerNet.layers.56.affine.fFeatures.2.actnorm.logs True
# module.flowUpsamplerNet.layers.56.affine.fFeatures.4.weight True
# module.flowUpsamplerNet.layers.56.affine.fFeatures.4.bias True
# module.flowUpsamplerNet.layers.56.affine.fFeatures.4.logs True
# module.flowUpsamplerNet.layers.57.actnorm.bias True
# module.flowUpsamplerNet.layers.57.actnorm.logs True
# module.flowUpsamplerNet.layers.57.invconv.weight True
# module.flowUpsamplerNet.layers.57.affine.fAffine.0.weight True
# module.flowUpsamplerNet.layers.57.affine.fAffine.0.actnorm.bias True
# module.flowUpsamplerNet.layers.57.affine.fAffine.0.actnorm.logs True
# module.flowUpsamplerNet.layers.57.affine.fAffine.2.weight True
# module.flowUpsamplerNet.layers.57.affine.fAffine.2.actnorm.bias True
# module.flowUpsamplerNet.layers.57.affine.fAffine.2.actnorm.logs True
# module.flowUpsamplerNet.layers.57.affine.fAffine.4.weight True
# module.flowUpsamplerNet.layers.57.affine.fAffine.4.bias True
# module.flowUpsamplerNet.layers.57.affine.fAffine.4.logs True
# module.flowUpsamplerNet.layers.57.affine.fFeatures.0.weight True
# module.flowUpsamplerNet.layers.57.affine.fFeatures.0.actnorm.bias True
# module.flowUpsamplerNet.layers.57.affine.fFeatures.0.actnorm.logs True
# module.flowUpsamplerNet.layers.57.affine.fFeatures.2.weight True
# module.flowUpsamplerNet.layers.57.affine.fFeatures.2.actnorm.bias True
# module.flowUpsamplerNet.layers.57.affine.fFeatures.2.actnorm.logs True
# module.flowUpsamplerNet.layers.57.affine.fFeatures.4.weight True
# module.flowUpsamplerNet.layers.57.affine.fFeatures.4.bias True
# module.flowUpsamplerNet.layers.57.affine.fFeatures.4.logs True
# module.flowUpsamplerNet.f.0.weight True
# module.flowUpsamplerNet.f.0.bias True
# rrdb params 702

# %%
#### resume training
if resume_state:
    logger.info('Resuming training from epoch: {}, iter: {}.'.format(
        resume_state['epoch'], resume_state['iter']))

    start_epoch = resume_state['epoch']
    current_step = resume_state['iter']
    model.resume_training(resume_state)  # handle optimizers and schedulers
else:
    current_step = 0
    start_epoch = 0
# Out:
# 21-07-06 12:20:52.664 - INFO: Resuming training from epoch: 0, iter: 4000.

# %%
train_loader = torch.utils.data.DataLoader(train_set, batch_size=16, shuffle=True,
                                           num_workers=1, drop_last=True,
                                           pin_memory=False)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
      for batch_idx, samples in enumerate(train_loader):
            model.feed_data(samples)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-f2f9595a6d9c> in <module>
#       5             # print(samples)
#       6
# ----> 7             model.feed_data(samples)
#
# /net/server2/homes/sep/minjun/research/SRFlow/code/models/SRFlow_model.py in feed_data(self, data, need_GT)
#     130
#     131     def feed_data(self, data, need_GT=True):
# --> 132         self.var_L = data['LQ'].to(self.device)  # LQ
#     133         if need_GT:
#     134             self.real_H = data['GT'].to(self.device)  # GT
#
# TypeError: list indices must be integers or slices, not str

# %%
print(train_data['LQ'].shape) 
print(train_data['GT'].shape) 
print(train_data['GT_path'])
# Out:
# torch.Size([12, 3, 40, 40])
# torch.Size([12, 3, 160, 160])
# ['31846', '19609', '133610', '10980', '57090', '4778', '147185', '70311', '109228', '50474', '15622', '64618']

# %%
#### training
timer = Timer()
#logger.info('Start training from epoch: {:d}, iter: {:d}'.format(start_epoch, current_step))
timerData = TickTock()

for epoch in range(start_epoch, total_epochs + 1):
    if opt['dist']:
        train_sampler.set_epoch(epoch)

    timerData.tick()
    for _, train_data in enumerate(train_loader):
        timerData.tock()
        current_step += 1
        if current_step > total_iters:
            break

        #### training
        model.feed_data(train_data)

        #### update learning rate
        model.update_learning_rate(current_step, warmup_iter=opt['train']['warmup_iter'])

        try:
            nll = model.optimize_parameters(current_step)
        except RuntimeError as e:
            print("Skipping ERROR caught in nll = model.optimize_parameters(current_step): ")
            print(e)

        if nll is None:
            nll = 0

        #### log
        def eta(t_iter):
            return (t_iter * (opt['train']['niter'] - current_step)) / 3600

        if current_step % opt['logger']['print_freq'] == 0 \
                or current_step - (resume_state['iter'] if resume_state else 0) < 25:
            avg_time = timer.get_average_and_reset()
            avg_data_time = timerData.get_average_and_reset()
            message = '<epoch:{:3d}, iter:{:8,d}, lr:{:.3e}, t:{:.2e}, td:{:.2e}, eta:{:.2e}, nll:{:.3e}> '.format(
                epoch, current_step, model.get_current_learning_rate(), avg_time, avg_data_time,
                eta(avg_time), nll)
            print(message)
        timer.tick()
        #Reduce number of logs
        if current_step % 5 == 0:
            tb_logger_train.add_scalar('loss/nll', nll, current_step)
            tb_logger_train.add_scalar('lr/base', model.get_current_learning_rate(), current_step)
            tb_logger_train.add_scalar('time/iteration', timer.get_last_iteration(), current_step)
            tb_logger_train.add_scalar('time/data', timerData.get_last_iteration(), current_step)
            tb_logger_train.add_scalar('time/eta', eta(timer.get_last_iteration()), current_step)
            for k, v in model.get_current_log().items():
                tb_logger_train.add_scalar(k, v, current_step)

        # validation
        if current_step % opt['train']['val_freq'] == 0 and rank <= 0:
            avg_psnr = 0.0
            idx = 0
            nlls = []
            for val_data in val_loader:
                idx += 1
                img_name = os.path.splitext(os.path.basename(val_data['LQ_path'][0]))[0]
                img_dir = os.path.join(opt['path']['val_images'], img_name)
                util.mkdir(img_dir)

                model.feed_data(val_data)

                nll = model.test()
                if nll is None:
                    nll = 0
                nlls.append(nll)

                visuals = model.get_current_visuals()

                sr_img = None
                # Save SR images for reference
                if hasattr(model, 'heats'):
                    for heat in model.heats:
                        for i in range(model.n_sample):
                            sr_img = util.tensor2img(visuals['SR', heat, i])  # uint8
                            save_img_path = os.path.join(img_dir,
                                                         '{:s}_{:09d}_h{:03d}_s{:d}.png'.format(img_name,
                                                                                                current_step,
                                                                                                int(heat * 100), i))
                            util.save_img(sr_img, save_img_path)
                else:
                    sr_img = util.tensor2img(visuals['SR'])  # uint8
                    save_img_path = os.path.join(img_dir,
                                                 '{:s}_{:d}.png'.format(img_name, current_step))
                    util.save_img(sr_img, save_img_path)
                assert sr_img is not None

                # Save LQ images for reference
                save_img_path_lq = os.path.join(img_dir,
                                                '{:s}_LQ.png'.format(img_name))
                if not os.path.isfile(save_img_path_lq):
                    lq_img = util.tensor2img(visuals['LQ'])  # uint8
                    util.save_img(
                        cv2.resize(lq_img, dsize=None, fx=opt['scale'], fy=opt['scale'],
                                   interpolation=cv2.INTER_NEAREST),
                        save_img_path_lq)

                # Save GT images for reference
                gt_img = util.tensor2img(visuals['GT'])  # uint8
                save_img_path_gt = os.path.join(img_dir,
                                                '{:s}_GT.png'.format(img_name))
                if not os.path.isfile(save_img_path_gt):
                    util.save_img(gt_img, save_img_path_gt)

                # calculate PSNR
                crop_size = opt['scale']
                gt_img = gt_img / 255.
                sr_img = sr_img / 255.
                cropped_sr_img = sr_img[crop_size:-crop_size, crop_size:-crop_size, :]
                cropped_gt_img = gt_img[crop_size:-crop_size, crop_size:-crop_size, :]
                avg_psnr += util.calculate_psnr(cropped_sr_img * 255, cropped_gt_img * 255)

            avg_psnr = avg_psnr / idx
            avg_nll = sum(nlls) / len(nlls)

            # log
            logger.info('# Validation # PSNR: {:.4e}'.format(avg_psnr))
            logger_val = logging.getLogger('val')  # validation logger
            logger_val.info('<epoch:{:3d}, iter:{:8,d}> psnr: {:.4e}'.format(
                epoch, current_step, avg_psnr))

            # tensorboard logger
            tb_logger_valid.add_scalar('loss/psnr', avg_psnr, current_step)
            tb_logger_valid.add_scalar('loss/nll', avg_nll, current_step)

            tb_logger_train.flush()
            tb_logger_valid.flush()

        #### save models and training states
        if current_step % opt['logger']['save_checkpoint_freq'] == 0:
            if rank <= 0:
                logger.info('Saving models and training states.')
                model.save(current_step)
                model.save_training_state(epoch, current_step)

        timerData.tick()

with open(os.path.join(opt['path']['root'], "TRAIN_DONE"), 'w') as f:
    f.write("TRAIN_DONE")

if rank <= 0:
    logger.info('Saving the final model.')
    model.save('latest')
    logger.info('End of training.')
# Out:
# /sep/minjun/anaconda3/envs/srflow/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /sep/minjun/anaconda3/envs/srflow/lib/python3.7/site-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# <epoch:  0, iter:       1, lr:2.500e-04, t:-1.00e+00, td:9.66e-01, eta:-5.56e+01, nll:-7.292e+00>
# <epoch:  0, iter:       2, lr:2.500e-04, t:-1.00e+00, td:1.09e-03, eta:-5.56e+01, nll:3.881e+01>
# <epoch:  0, iter:       3, lr:2.500e-04, t:4.95e+00, td:2.12e-03, eta:2.75e+02, nll:5.116e+01>
# <epoch:  0, iter:       4, lr:2.500e-04, t:2.59e+00, td:3.46e-03, eta:1.44e+02, nll:2.874e+00>
# <epoch:  0, iter:       5, lr:2.500e-04, t:2.91e+00, td:9.20e-04, eta:1.62e+02, nll:-1.009e+00>
# <epoch:  0, iter:       6, lr:2.500e-04, t:2.59e+00, td:1.24e-03, eta:1.44e+02, nll:-2.737e+00>
# <epoch:  0, iter:       7, lr:2.500e-04, t:2.57e+00, td:2.17e-03, eta:1.43e+02, nll:-3.300e+00>
# <epoch:  0, iter:       8, lr:2.500e-04, t:2.58e+00, td:2.18e-03, eta:1.43e+02, nll:-3.309e+00>
# <epoch:  0, iter:       9, lr:2.500e-04, t:2.87e+00, td:2.09e-03, eta:1.59e+02, nll:-3.700e+00>
# <epoch:  0, iter:      10, lr:2.500e-04, t:2.64e+00, td:2.26e-03, eta:1.47e+02, nll:-4.664e+00>
# <epoch:  0, iter:      11, lr:2.500e-04, t:2.67e+00, td:2.54e-03, eta:1.49e+02, nll:-5.326e+00>
# <epoch:  0, iter:      12, lr:2.500e-04, t:2.74e+00, td:2.27e-03, eta:1.52e+02, nll:-5.678e+00>
# <epoch:  0, iter:      13, lr:2.500e-04, t:2.60e+00, td:2.26e-03, eta:1.44e+02, nll:-5.289e+00>
# <epoch:  0, iter:      14, lr:2.500e-04, t:2.80e+00, td:2.27e-03, eta:1.56e+02, nll:-6.062e+00>
# <epoch:  0, iter:      15, lr:2.500e-04, t:2.58e+00, td:2.20e-03, eta:1.44e+02, nll:-6.628e+00>
# <epoch:  0, iter:      16, lr:2.500e-04, t:2.61e+00, td:2.43e-03, eta:1.45e+02, nll:-5.718e+00>
# <epoch:  0, iter:      17, lr:2.500e-04, t:2.64e+00, td:2.57e-03, eta:1.47e+02, nll:-6.679e+00>
# <epoch:  0, iter:      18, lr:2.500e-04, t:2.88e+00, td:2.41e-03, eta:1.60e+02, nll:-6.146e+00>
# <epoch:  0, iter:      19, lr:2.500e-04, t:2.62e+00, td:2.19e-03, eta:1.45e+02, nll:-6.093e+00>
# <epoch:  0, iter:      20, lr:2.500e-04, t:2.59e+00, td:2.38e-03, eta:1.44e+02, nll:-6.075e+00>
# <epoch:  0, iter:      21, lr:2.500e-04, t:2.57e+00, td:2.84e-03, eta:1.42e+02, nll:-6.458e+00>
# <epoch:  0, iter:      22, lr:2.500e-04, t:2.82e+00, td:2.30e-03, eta:1.57e+02, nll:-6.634e+00>
# <epoch:  0, iter:      23, lr:2.500e-04, t:2.58e+00, td:1.93e-03, eta:1.43e+02, nll:-7.251e+00>
# <epoch:  0, iter:      24, lr:2.500e-04, t:2.59e+00, td:2.24e-03, eta:1.44e+02, nll:-6.264e+00>
# <epoch:  0, iter:     100, lr:2.500e-04, t:2.64e+00, td:1.96e-03, eta:1.47e+02, nll:-1.078e+01>
# <epoch:  0, iter:     200, lr:2.500e-04, t:2.63e+00, td:1.92e-03, eta:1.46e+02, nll:-1.195e+01>
# <epoch:  0, iter:     300, lr:2.500e-04, t:2.63e+00, td:1.92e-03, eta:1.46e+02, nll:-1.301e+01>
# <epoch:  0, iter:     400, lr:2.500e-04, t:2.62e+00, td:1.91e-03, eta:1.45e+02, nll:-1.552e+01>
# <epoch:  0, iter:     500, lr:2.500e-04, t:2.63e+00, td:1.89e-03, eta:1.46e+02, nll:-1.344e+01>
# <epoch:  0, iter:     600, lr:2.500e-04, t:2.62e+00, td:1.91e-03, eta:1.45e+02, nll:-1.305e+01>
# <epoch:  0, iter:     700, lr:2.500e-04, t:2.62e+00, td:1.89e-03, eta:1.45e+02, nll:-1.387e+01>
# <epoch:  0, iter:     800, lr:2.500e-04, t:2.62e+00, td:1.90e-03, eta:1.45e+02, nll:-1.267e+01>
# <epoch:  0, iter:     900, lr:2.500e-04, t:2.61e+00, td:1.89e-03, eta:1.44e+02, nll:-1.309e+01>
# 21-07-01 12:22:10.522 - INFO: Saving models and training states.
# 21-07-01 12:22:10.522 - INFO: Saving models and training states.
# 21-07-01 12:22:10.522 - INFO: Saving models and training states.
# <epoch:  0, iter:   1,000, lr:2.500e-04, t:2.62e+00, td:1.93e-03, eta:1.45e+02, nll:-1.459e+01>
# <epoch:  0, iter:   1,100, lr:2.500e-04, t:2.70e+00, td:1.89e-03, eta:1.49e+02, nll:-1.523e+01>
# <epoch:  0, iter:   1,200, lr:2.500e-04, t:2.63e+00, td:1.90e-03, eta:1.45e+02, nll:-1.711e+01>
# <epoch:  0, iter:   1,300, lr:2.500e-04, t:2.62e+00, td:1.90e-03, eta:1.45e+02, nll:-1.600e+01>
# <epoch:  0, iter:   1,400, lr:2.500e-04, t:2.63e+00, td:1.93e-03, eta:1.45e+02, nll:-1.602e+01>
# <epoch:  0, iter:   1,500, lr:2.500e-04, t:2.64e+00, td:1.95e-03, eta:1.45e+02, nll:-1.575e+01>
# <epoch:  0, iter:   1,600, lr:2.500e-04, t:2.61e+00, td:1.89e-03, eta:1.44e+02, nll:-1.435e+01>
# <epoch:  0, iter:   1,700, lr:2.500e-04, t:2.60e+00, td:1.89e-03, eta:1.43e+02, nll:-1.316e+01>
# <epoch:  0, iter:   1,800, lr:2.500e-04, t:2.59e+00, td:1.91e-03, eta:1.43e+02, nll:-1.518e+01>
# <epoch:  0, iter:   1,900, lr:2.500e-04, t:2.59e+00, td:1.91e-03, eta:1.43e+02, nll:-1.455e+01>
# 21-07-01 13:05:51.119 - INFO: Saving models and training states.
# 21-07-01 13:05:51.119 - INFO: Saving models and training states.
# 21-07-01 13:05:51.119 - INFO: Saving models and training states.
# <epoch:  0, iter:   2,000, lr:2.500e-04, t:2.60e+00, td:1.90e-03, eta:1.43e+02, nll:-1.508e+01>
# <epoch:  0, iter:   2,100, lr:2.500e-04, t:2.68e+00, td:1.92e-03, eta:1.47e+02, nll:-1.499e+01>
# <epoch:  0, iter:   2,200, lr:2.500e-04, t:2.61e+00, td:1.88e-03, eta:1.44e+02, nll:-1.582e+01>
# <epoch:  0, iter:   2,300, lr:2.500e-04, t:2.60e+00, td:1.88e-03, eta:1.43e+02, nll:-1.522e+01>
# <epoch:  0, iter:   2,400, lr:2.500e-04, t:2.60e+00, td:1.94e-03, eta:1.43e+02, nll:-1.589e+01>
# <epoch:  0, iter:   2,500, lr:2.500e-04, t:2.61e+00, td:1.91e-03, eta:1.43e+02, nll:-1.626e+01>
# <epoch:  0, iter:   2,600, lr:2.500e-04, t:2.60e+00, td:1.92e-03, eta:1.43e+02, nll:-1.606e+01>
# <epoch:  0, iter:   2,700, lr:2.500e-04, t:2.60e+00, td:1.91e-03, eta:1.43e+02, nll:-1.576e+01>
# <epoch:  0, iter:   2,800, lr:2.500e-04, t:2.60e+00, td:1.91e-03, eta:1.42e+02, nll:-1.825e+01>
# <epoch:  0, iter:   2,900, lr:2.500e-04, t:2.60e+00, td:1.86e-03, eta:1.43e+02, nll:-1.621e+01>
# 21-07-01 13:49:22.602 - INFO: Saving models and training states.
# 21-07-01 13:49:22.602 - INFO: Saving models and training states.
# 21-07-01 13:49:22.602 - INFO: Saving models and training states.
# <epoch:  0, iter:   3,000, lr:2.500e-04, t:2.61e+00, td:1.90e-03, eta:1.43e+02, nll:-1.553e+01>
# <epoch:  0, iter:   3,100, lr:2.500e-04, t:2.67e+00, td:1.89e-03, eta:1.46e+02, nll:-1.635e+01>
# <epoch:  0, iter:   3,200, lr:2.500e-04, t:2.59e+00, td:1.88e-03, eta:1.42e+02, nll:-1.701e+01>
# <epoch:  0, iter:   3,300, lr:2.500e-04, t:2.60e+00, td:1.89e-03, eta:1.42e+02, nll:-1.557e+01>
# <epoch:  0, iter:   3,400, lr:2.500e-04, t:2.59e+00, td:1.89e-03, eta:1.41e+02, nll:-1.507e+01>
# <epoch:  0, iter:   3,500, lr:2.500e-04, t:2.60e+00, td:1.92e-03, eta:1.42e+02, nll:-1.377e+01>
# <epoch:  0, iter:   3,600, lr:2.500e-04, t:2.60e+00, td:1.95e-03, eta:1.42e+02, nll:-1.604e+01>
# <epoch:  0, iter:   3,700, lr:2.500e-04, t:2.60e+00, td:1.96e-03, eta:1.42e+02, nll:-1.474e+01>
# <epoch:  0, iter:   3,800, lr:2.500e-04, t:2.60e+00, td:1.95e-03, eta:1.42e+02, nll:-1.466e+01>
# <epoch:  0, iter:   3,900, lr:2.500e-04, t:2.59e+00, td:1.90e-03, eta:1.41e+02, nll:-1.575e+01>
# 21-07-01 14:32:45.912 - INFO: Saving models and training states.
# 21-07-01 14:32:45.912 - INFO: Saving models and training states.
# 21-07-01 14:32:45.912 - INFO: Saving models and training states.
# <epoch:  0, iter:   4,000, lr:2.500e-04, t:2.60e+00, td:1.86e-03, eta:1.42e+02, nll:-1.692e+01>
# <epoch:  0, iter:   4,100, lr:2.500e-04, t:2.68e+00, td:1.88e-03, eta:1.46e+02, nll:-1.406e+01>
# <epoch:  0, iter:   4,200, lr:2.500e-04, t:2.61e+00, td:1.88e-03, eta:1.42e+02, nll:-1.629e+01>
# <epoch:  0, iter:   4,300, lr:2.500e-04, t:2.60e+00, td:1.88e-03, eta:1.41e+02, nll:-1.665e+01>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-bc6bb16ab4f8> in <module>
#      22
#      23         try:
# ---> 24             nll = model.optimize_parameters(current_step)
#      25         except RuntimeError as e:
#      26             print("Skipping ERROR caught in nll = model.optimize_parameters(current_step): ")
#
# /net/server2/homes/sep/minjun/research/SRFlow/code/models/SRFlow_model.py in optimize_parameters(self, step)
#     152         weight_fl = 1 if weight_fl is None else weight_fl
#     153         if weight_fl > 0:
# --> 154             z, nll, y_logits = self.netG(gt=self.real_H, lr=self.var_L, reverse=False)
#     155             nll_loss = torch.mean(nll)
#     156             losses['nll_loss'] = nll_loss * weight_fl
#
# /sep/minjun/anaconda3/envs/srflow/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /sep/minjun/anaconda3/envs/srflow/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     165             return self.module(*inputs[0], **kwargs[0])
#     166         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
# --> 167         outputs = self.parallel_apply(replicas, inputs, kwargs)
#     168         return self.gather(outputs, self.output_device)
#     169
#
# /sep/minjun/anaconda3/envs/srflow/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in parallel_apply(self, replicas, inputs, kwargs)
#     175
#     176     def parallel_apply(self, replicas, inputs, kwargs):
# --> 177         return parallel_apply(replicas, inputs, kwargs, self.device_ids[:len(replicas)])
#     178
#     179     def gather(self, outputs, output_device):
#
# /sep/minjun/anaconda3/envs/srflow/lib/python3.7/site-packages/torch/nn/parallel/parallel_apply.py in parallel_apply(modules, inputs, kwargs_tup, devices)
#      76             thread.start()
#      77         for thread in threads:
# ---> 78             thread.join()
#      79     else:
#      80         _worker(0, modules[0], inputs[0], kwargs_tup[0], devices[0])
#
# /sep/minjun/anaconda3/envs/srflow/lib/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# /sep/minjun/anaconda3/envs/srflow/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:

# %%
#!pip install light-the-torch

# %%
#!ltt install torch torchvision
